# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pyplot
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("FinancialMarketData.csv")

# %%
df
# Out:
#            Unnamed: 0 Unnamed: 1      Unnamed: 2  \
# 0     EURUSDV3M Index        NaN             NaN
# 1                 NaN        NaN  Show/Hide data
# 2                 676        NaN            Name
# 3                 NaN        NaN  Index Currency
# 4                 NaN        NaN          Ticker
# ...               ...        ...             ...
# 1149              NaN        NaN       3/23/2021
# 1150              NaN        NaN       3/30/2021
# 1151              NaN        NaN        4/6/2021
# 1152              NaN        NaN       4/13/2021
# 1153              NaN        NaN       4/20/2021
#
#                         Unnamed: 3      Unnamed: 4  Unnamed: 5 Unnamed: 6  \
# 0     Fixed Income, MM & Interbank             NaN         NaN        NaN
# 1                                S               H           H          H
# 2                              NaN             NaN         NaN        NaN
# 3                              NaN             NaN         NaN        NaN
# 4                  XAU BGNL Curncy  ECSURPUS Index  BDIY Index  CRY Index
# ...                            ...             ...         ...        ...
# 1149                      1727.960           0.339    2271.000    184.502
# 1150                      1685.560           0.303    2103.000    184.874
# 1151                      1743.280           0.440    2092.000    185.839
# 1152                      1742.690           0.467    2140.000    188.137
# 1153                      1779.720           0.492    2432.000    193.804
#
#       Unnamed: 7  Unnamed: 8  Unnamed: 9  ... Unnamed: 50 Unnamed: 51  \
# 0            NaN         NaN         NaN  ...    Treasury        Gold
# 1              H           H           H  ...           H           H
# 2            NaN         NaN         NaN  ...         NaN         NaN
# 3            NaN         NaN         NaN  ...         NaN         NaN
# 4     DXY Curncy  JPY Curncy  GBP Curncy  ...  TY1 Comdty  GC1 Comdty
# ...          ...         ...         ...  ...         ...         ...
# 1149      92.336     108.720       1.376  ...     131.922    1725.100
# 1150      93.297     110.290       1.372  ...     131.188    1683.900
# 1151      92.335     109.880       1.382  ...     131.688    1741.500
# 1152      91.852     109.190       1.374  ...     132.078    1746.200
# 1153      91.147     108.090       1.395  ...     132.547    1774.900
#
#      Unnamed: 52 Unnamed: 53 Unnamed: 54 Unnamed: 55 Unnamed: 56 Unnamed: 57  \
# 0          Brent         S&P   Eurostoxx      Nasdaq          EM       Japan
# 1              H           H           H           H           H           H
# 2            NaN         NaN         NaN         NaN         NaN         NaN
# 3            NaN         NaN         NaN         NaN         NaN         NaN
# 4     CO1 Comdty   ES1 Index   VG1 Index   NQ1 Index  LLL1 Index   TP1 Index
# ...          ...         ...         ...         ...         ...         ...
# 1149      60.790    3899.800    3773.000   13006.250    1103.600    1958.500
# 1150      64.140    3947.700    3872.000   12878.250    1103.600    1978.000
# 1151      62.740    4064.000    3920.000   13570.000    1103.600    1955.000
# 1152      63.670    4132.800    3917.000   13975.750    1103.600    1961.500
# 1153      66.510    4127.000    3902.000   13802.750    1103.600    1927.000
#
#      Unnamed: 58 Unnamed: 59
# 0         2Y Ger       2Y US
# 1              H           H
# 2            NaN         NaN
# 3            NaN         NaN
# 4     DU1 Comdty  TU2 Comdty
# ...          ...         ...
# 1149     112.140     110.383
# 1150     112.090     110.387
# 1151     112.120     110.281
# 1152     112.115     110.293
# 1153     112.100     110.293
#
# [1154 rows x 60 columns]
